# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
# Load features
features = pd.read_csv('../data/processed/features.csv')

# %%
print("=" * 70)
print("FEATURE MATRIX OVERVIEW")
print("=" * 70)
print(f"\nShape: {features.shape}")
print(f"Rows (records): {features.shape[0]:,}")
print(f"Columns (features): {features.shape[1]}")
# Out:
# ======================================================================
# FEATURE MATRIX OVERVIEW
# ======================================================================
#
# Shape: (28800, 29)
# Rows (records): 28,800
# Columns (features): 29

# %%
print("\nFirst few rows:")
print(features.head())

print("\nFeature names:")
print(features.columns.tolist())

print("\nData types:")
print(features.dtypes)

print("\nBasic statistics:")
print(features.describe())
# Out:
# First few rows:
#   customer_id year_month  churned  logins_per_day  api_calls  \
# 0   CUST_0001    2023-01        0        0.991683       1343
# 1   CUST_0001    2023-01        0        0.393335       1134
# 2   CUST_0001    2023-03        0        3.937638       1054
# 3   CUST_0001    2023-04        0        2.787162       1511
# 4   CUST_0001    2023-05        0        3.190330       1171
#
#    features_used_count  days_inactive  support_tickets  engagement_score  \
# 0                    1             40                1              16.4
# 1                    7             19                1              37.1
# 2                    2              6                2              47.7
# 3                    6             10                4              50.0
# 4                    4             34                3              37.4
#
#    logins_3m_avg  ...  flag_no_login_60days  flag_low_feature_adoption  \
# 0       0.991683  ...                     0                          1
# 1       0.692509  ...                     0                          0
# 2       1.774219  ...                     0                          1
# 3       2.372712  ...                     0                          0
# 4       3.305043  ...                     0                          0
#
#    flag_high_support_tickets  flag_declining_engagement  risk_flag_count  \
# 0                          0                          1                3
# 1                          0                          1                1
# 2                          0                          1                2
# 3                          1                          1                2
# 4                          1                          1                3
#
#    health_score  company_size  subscription_tier  industry  monthly_revenue
# 0     31.833333         small            Starter    Retail              500
# 1     50.408333         small            Starter    Retail              500
# 2     40.850000         small            Starter    Retail              500
# 3     41.258333         small            Starter    Retail              500
# 4     34.983333         small            Starter    Retail              500
#
# [5 rows x 29 columns]
#
# Feature names:
# ['customer_id', 'year_month', 'churned', 'logins_per_day', 'api_calls', 'features_used_count', 'days_inactive', 'support_tickets', 'engagement_score', 'logins_3m_avg', 'api_calls_3m_avg', 'features_3m_avg', 'logins_trend_3m', 'engagement_decay', 'recency_score', 'feature_adoption_rate', 'is_high_adoption', 'is_low_adoption', 'flag_no_login_30days', 'flag_no_login_60days', 'flag_low_feature_adoption', 'flag_high_support_tickets', 'flag_declining_engagement', 'risk_flag_count', 'health_score', 'company_size', 'subscription_tier', 'industry', 'monthly_revenue']
#
# Data types:
# customer_id                      str
# year_month                       str
# churned                        int64
# logins_per_day               float64
# api_calls                      int64
# features_used_count            int64
# days_inactive                  int64
# support_tickets                int64
# engagement_score             float64
# logins_3m_avg                float64
# api_calls_3m_avg             float64
# features_3m_avg              float64
# logins_trend_3m              float64
# engagement_decay             float64
# recency_score                float64
# feature_adoption_rate        float64
# is_high_adoption               int64
# is_low_adoption                int64
# flag_no_login_30days           int64
# flag_no_login_60days           int64
# flag_low_feature_adoption      int64
# flag_high_support_tickets      int64
# flag_declining_engagement      int64
# risk_flag_count                int64
# health_score                 float64
# company_size                     str
# subscription_tier                str
# industry                         str
# monthly_revenue                int64
# dtype: object
#
# Basic statistics:
#             churned  logins_per_day      api_calls  features_used_count  \
# count  28800.000000    28800.000000   28800.000000         28800.000000
# mean       0.082743        2.604371   18152.962049             5.490139
# std        0.275498        1.383832   36553.632226             2.875093
# min        0.000000        0.200052     100.000000             1.000000
# 25%        0.000000        1.413397    1005.000000             3.000000
# 50%        0.000000        2.595560    2136.000000             5.000000
# 75%        0.000000        3.794875   12012.000000             8.000000
# max        1.000000        4.999866  256202.000000            10.000000
#
#        days_inactive  support_tickets  engagement_score  logins_3m_avg  \
# count   28800.000000     28800.000000      28800.000000   28800.000000
# mean       29.324514         2.001528         42.833628       2.604340
# std        17.364122         1.414262         13.196845       0.823581
# min         0.000000         0.000000          5.400000       0.203012
# 25%        14.000000         1.000000         33.600000       2.030213
# 50%        29.000000         2.000000         42.600000       2.605904
# 75%        44.000000         3.000000         51.800000       3.181488
# max        59.000000         4.000000         91.500000       4.999276
#
#        api_calls_3m_avg  features_3m_avg  ...  is_high_adoption  \
# count      28800.000000     28800.000000  ...      28800.000000
# mean       18172.929942         5.489693  ...          0.298993
# std        34570.187822         1.710630  ...          0.457825
# min          100.000000         1.000000  ...          0.000000
# 25%         1007.666667         4.333333  ...          0.000000
# 50%         5416.833333         5.333333  ...          0.000000
# 75%        11208.333333         6.666667  ...          1.000000
# max       198568.000000        10.000000  ...          1.000000
#
#        is_low_adoption  flag_no_login_30days  flag_no_login_60days  \
# count     28800.000000          28800.000000               28800.0
# mean          0.200660              0.497431                   0.0
# std           0.400501              0.500002                   0.0
# min           0.000000              0.000000                   0.0
# 25%           0.000000              0.000000                   0.0
# 50%           0.000000              0.000000                   0.0
# 75%           0.000000              1.000000                   0.0
# max           1.000000              1.000000                   0.0
#
#        flag_low_feature_adoption  flag_high_support_tickets  \
# count               28800.000000               28800.000000
# mean                    0.200660                   0.400069
# std                     0.400501                   0.489921
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   1.000000
# max                     1.000000                   1.000000
#
#        flag_declining_engagement  risk_flag_count  health_score  \
# count               28800.000000     28800.000000  28800.000000
# mean                    0.405000         1.503160     42.505239
# std                     0.490901         0.937724     11.030579
# min                     0.000000         0.000000      7.500000
# 25%                     0.000000         1.000000     34.750000
# 50%                     0.000000         1.000000     42.587500
# 75%                     1.000000         2.000000     50.316667
# max                     1.000000         4.000000     76.500000
#
#        monthly_revenue
# count     28800.000000
# mean       2558.125000
# std        3125.163692
# min         500.000000
# 25%         500.000000
# 50%        2500.000000
# 75%        2500.000000
# max       10000.000000
#
# [8 rows x 24 columns]
